# %%
# !pip install gymnasium
# Out:
# Collecting gymnasium
#   Downloading gymnasium-1.3.0-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: numpy>=1.21.0 in c:\users\radhagopinath\anaconda3\lib\site-packages (from gymnasium) (2.1.3)
# Requirement already satisfied: cloudpickle>=1.2.0 in c:\users\radhagopinath\anaconda3\lib\site-packages (from gymnasium) (3.0.0)
# Requirement already satisfied: typing-extensions>=4.3.0 in c:\users\radhagopinath\anaconda3\lib\site-packages (from gymnasium) (4.12.2)
# Collecting farama-notifications>=0.0.1 (from gymnasium)
#   Downloading farama_notifications-0.0.6-py3-none-any.whl.metadata (729 bytes)
# Downloading gymnasium-1.3.0-py3-none-any.whl (953 kB)
#    ---------------------------------------- 0.0/953.9 kB ? eta -:--:--
#    ---------- ----------------------------- 262.1/953.9 kB ? eta -:--:--
#    -------------------------------- ------- 786.4/953.9 kB 2.5 MB/s eta 0:00:01
#    ---------------------------------------- 953.9/953.9 kB 1.9 MB/s eta 0:00:00
# Downloading farama_notifications-0.0.6-py3-none-any.whl (2.9 kB)
# Installing collected packages: farama-notifications, gymnasium
#
#    -------------------- ------------------- 1/2 [gymnasium]
#    -------------------- ------------------- 1/2 [gymnasium]
#    -------------------- ------------------- 1/2 [gymnasium]
#    -------------------- ------------------- 1/2 [gymnasium]
#    -------------------- ------------------- 1/2 [gymnasium]
#    -------------------- ------------------- 1/2 [gymnasium]
#    -------------------- ------------------- 1/2 [gymnasium]
#    -------------------- ------------------- 1/2 [gymnasium]
#    -------------------- ------------------- 1/2 [gymnasium]
#    -------------------- ------------------- 1/2 [gymnasium]
#    -------------------- ------------------- 1/2 [gymnasium]
#    -------------------- ------------------- 1/2 [gymnasium]
#    -------------------- ------------------- 1/2 [gymnasium]
#    -------------------- ------------------- 1/2 [gymnasium]
#    ---------------------------------------- 2/2 [gymnasium]
#
# Successfully installed farama-notifications-0.0.6 gymnasium-1.3.0

# %%
# !pip install "gymnasium[toy-text]"
# Out:
# Requirement already satisfied: gymnasium[toy-text] in c:\users\radhagopinath\anaconda3\lib\site-packages (1.3.0)
# Requirement already satisfied: numpy>=1.21.0 in c:\users\radhagopinath\anaconda3\lib\site-packages (from gymnasium[toy-text]) (2.1.3)
# Requirement already satisfied: cloudpickle>=1.2.0 in c:\users\radhagopinath\anaconda3\lib\site-packages (from gymnasium[toy-text]) (3.0.0)
# Requirement already satisfied: typing-extensions>=4.3.0 in c:\users\radhagopinath\anaconda3\lib\site-packages (from gymnasium[toy-text]) (4.12.2)
# Requirement already satisfied: farama-notifications>=0.0.1 in c:\users\radhagopinath\anaconda3\lib\site-packages (from gymnasium[toy-text]) (0.0.6)
# Collecting pygame-ce>=2.1.3 (from gymnasium[toy-text])
#   Downloading pygame_ce-2.5.7-cp313-cp313-win_amd64.whl.metadata (11 kB)
# Downloading pygame_ce-2.5.7-cp313-cp313-win_amd64.whl (10.4 MB)
#    ---------------------------------------- 0.0/10.4 MB ? eta -:--:--
#    ---------------------------------------- 0.0/10.4 MB ? eta -:--:--
#    ---------------------------------------- 0.0/10.4 MB ? eta -:--:--
#    - -------------------------------------- 0.3/10.4 MB ? eta -:--:--
#    - -------------------------------------- 0.3/10.4 MB ? eta -:--:--
#    - -------------------------------------- 0.3/10.4 MB ? eta -:--:--
#    - -------------------------------------- 0.3/10.4 MB ? eta -:--:--
#    - -------------------------------------- 0.3/10.4 MB ? eta -:--:--
#    -- ------------------------------------- 0.5/10.4 MB 243.2 kB/s eta 0:00:41
#    --- ------------------------------------ 0.8/10.4 MB 395.6 kB/s eta 0:00:25
#    ------ --------------------------------- 1.6/10.4 MB 809.6 kB/s eta 0:00:11
#    ------- -------------------------------- 1.8/10.4 MB 932.1 kB/s eta 0:00:10
#    -------- ------------------------------- 2.1/10.4 MB 994.8 kB/s eta 0:00:09
#    ---------- ----------------------------- 2.6/10.4 MB 1.1 MB/s eta 0:00:08
#    ----------- ---------------------------- 2.9/10.4 MB 1.1 MB/s eta 0:00:07
#    -------------- ------------------------- 3.7/10.4 MB 1.3 MB/s eta 0:00:06
#    ---------------- ----------------------- 4.2/10.4 MB 1.4 MB/s eta 0:00:05
#    ------------------- -------------------- 5.0/10.4 MB 1.5 MB/s eta 0:00:04
#    -------------------- ------------------- 5.2/10.4 MB 1.6 MB/s eta 0:00:04
#    --------------------- ------------------ 5.5/10.4 MB 1.5 MB/s eta 0:00:04
#    ------------------------- -------------- 6.6/10.4 MB 1.7 MB/s eta 0:00:03
#    ---------------------------- ----------- 7.3/10.4 MB 1.8 MB/s eta 0:00:02
#    -------------------------------- ------- 8.4/10.4 MB 2.0 MB/s eta 0:00:02
#    ------------------------------------ --- 9.4/10.4 MB 2.1 MB/s eta 0:00:01
#    ---------------------------------------  10.2/10.4 MB 2.2 MB/s eta 0:00:01
#    ---------------------------------------- 10.4/10.4 MB 2.2 MB/s eta 0:00:00
# Installing collected packages: pygame-ce
# Successfully installed pygame-ce-2.5.7

# %%
import gymnasium as gym
import numpy as np
import random

# %%
#sample env
env=gym.make("CliffWalking-v1")

# %%
env
# Out:
# <OrderEnforcing<PassiveEnvChecker<CliffWalkingEnv<CliffWalking-v1>>>>

# %%
print(env.observation_space.n) #states
print(env.action_space.n) #actions

starting_state,_=env.reset() #3*12+0=36
print(starting_state)
# Out:
# 48
# 4
# 36

# %%
#SARSA
epsilon=0.1
gamma=0.99
alpha=0.5
episodes=500

# %%
#Q table->stores Q values
Q=np.zeros((48,4))

# %%
#policy: state-->action
def epsilon_greedy(state):
    if random.random()<epsilon:
        return env.action_space.sample() #random action->explore
    else:
        return np.argmax(Q[state]) #exploit

# %%
for episode in range(episodes):

    render=(episode%50==0)
    if render:
        env = gym.make("CliffWalking-v1", render_mode="human")
        print(f"rendering env for episode={episode+1}/500")
    else:
        env=gym.make("CliffWalking-v1")
    done=False #when the episode has ended
    state,_=env.reset()
    action=epsilon_greedy(state)

    total_reward=0
    episode_len=0

    while not done:
        next_state,reward,terminated,truncated,_=env.step(action)
        done=terminated or truncated
        next_action=epsilon_greedy(next_state)

        #sarsa update
        Q[state, action] += alpha * (reward + gamma * Q[next_state, next_action] - Q[state, action])

        state=next_state
        action=next_action

        total_reward+=reward
        episode_len+=1

    print(f"for episode={episode+1}: total reward={total_reward} and episode length={episode_len}")
    env.close()
# Out:
# rendering env for episode=1/500
# for episode=1: total reward=-21 and episode length=21
# for episode=2: total reward=-21 and episode length=21
# for episode=3: total reward=-20 and episode length=20
# for episode=4: total reward=-19 and episode length=19
# for episode=5: total reward=-21 and episode length=21
# for episode=6: total reward=-17 and episode length=17
# for episode=7: total reward=-21 and episode length=21
# for episode=8: total reward=-22 and episode length=22
# for episode=9: total reward=-25 and episode length=25
# for episode=10: total reward=-19 and episode length=19
# for episode=11: total reward=-17 and episode length=17
# for episode=12: total reward=-17 and episode length=17
# for episode=13: total reward=-17 and episode length=17
# for episode=14: total reward=-24 and episode length=24
# for episode=15: total reward=-17 and episode length=17
# for episode=16: total reward=-17 and episode length=17
# for episode=17: total reward=-17 and episode length=17
# for episode=18: total reward=-21 and episode length=21
# for episode=19: total reward=-20 and episode length=20
# for episode=20: total reward=-17 and episode length=17
# for episode=21: total reward=-117 and episode length=18
# for episode=22: total reward=-17 and episode length=17
# for episode=23: total reward=-17 and episode length=17
# for episode=24: total reward=-20 and episode length=20
# for episode=25: total reward=-17 and episode length=17
# for episode=26: total reward=-20 and episode length=20
# for episode=27: total reward=-17 and episode length=17
# for episode=28: total reward=-19 and episode length=19
# for episode=29: total reward=-23 and episode length=23
# for episode=30: total reward=-25 and episode length=25
# for episode=31: total reward=-19 and episode length=19
# for episode=32: total reward=-24 and episode length=24
# for episode=33: total reward=-18 and episode length=18
# for episode=34: total reward=-17 and episode length=17
# for episode=35: total reward=-21 and episode length=21
# for episode=36: total reward=-20 and episode length=20
# for episode=37: total reward=-23 and episode length=23
# for episode=38: total reward=-21 and episode length=21
# for episode=39: total reward=-19 and episode length=19
# for episode=40: total reward=-23 and episode length=23
# for episode=41: total reward=-17 and episode length=17
# for episode=42: total reward=-20 and episode length=20
# for episode=43: total reward=-19 and episode length=19
# for episode=44: total reward=-17 and episode length=17
# for episode=45: total reward=-17 and episode length=17
# for episode=46: total reward=-19 and episode length=19
# for episode=47: total reward=-25 and episode length=25
# for episode=48: total reward=-17 and episode length=17
# for episode=49: total reward=-21 and episode length=21
# for episode=50: total reward=-17 and episode length=17
# rendering env for episode=51/500
# for episode=51: total reward=-25 and episode length=25
# for episode=52: total reward=-25 and episode length=25
# for episode=53: total reward=-19 and episode length=19
# for episode=54: total reward=-19 and episode length=19
# for episode=55: total reward=-21 and episode length=21
# for episode=56: total reward=-17 and episode length=17
# for episode=57: total reward=-121 and episode length=22
# for episode=58: total reward=-23 and episode length=23
# for episode=59: total reward=-20 and episode length=20
# for episode=60: total reward=-35 and episode length=35
# for episode=61: total reward=-19 and episode length=19
# for episode=62: total reward=-17 and episode length=17
# for episode=63: total reward=-21 and episode length=21
# for episode=64: total reward=-19 and episode length=19
# for episode=65: total reward=-17 and episode length=17
# for episode=66: total reward=-17 and episode length=17
# for episode=67: total reward=-18 and episode length=18
# for episode=68: total reward=-25 and episode length=25
# for episode=69: total reward=-18 and episode length=18
# for episode=70: total reward=-17 and episode length=17
# for episode=71: total reward=-20 and episode length=20
# for episode=72: total reward=-18 and episode length=18
# for episode=73: total reward=-20 and episode length=20
# for episode=74: total reward=-17 and episode length=17
# for episode=75: total reward=-17 and episode length=17
# for episode=76: total reward=-18 and episode length=18
# for episode=77: total reward=-17 and episode length=17
# for episode=78: total reward=-20 and episode length=20
# for episode=79: total reward=-23 and episode length=23
# for episode=80: total reward=-29 and episode length=29
# for episode=81: total reward=-20 and episode length=20
# for episode=82: total reward=-17 and episode length=17
# for episode=83: total reward=-19 and episode length=19
# for episode=84: total reward=-17 and episode length=17
# for episode=85: total reward=-17 and episode length=17
# for episode=86: total reward=-19 and episode length=19
# for episode=87: total reward=-21 and episode length=21
# for episode=88: total reward=-17 and episode length=17
# for episode=89: total reward=-21 and episode length=21
# for episode=90: total reward=-18 and episode length=18
# for episode=91: total reward=-23 and episode length=23
# for episode=92: total reward=-18 and episode length=18
# for episode=93: total reward=-19 and episode length=19
# for episode=94: total reward=-18 and episode length=18
# for episode=95: total reward=-19 and episode length=19
# for episode=96: total reward=-17 and episode length=17
# for episode=97: total reward=-19 and episode length=19
# for episode=98: total reward=-118 and episode length=19
# for episode=99: total reward=-21 and episode length=21
# for episode=100: total reward=-22 and episode length=22
# rendering env for episode=101/500
# for episode=101: total reward=-22 and episode length=22
# for episode=102: total reward=-132 and episode length=33
# for episode=103: total reward=-17 and episode length=17
# for episode=104: total reward=-26 and episode length=26
# for episode=105: total reward=-25 and episode length=25
# for episode=106: total reward=-21 and episode length=21
# for episode=107: total reward=-17 and episode length=17
# for episode=108: total reward=-27 and episode length=27
# for episode=109: total reward=-23 and episode length=23
# for episode=110: total reward=-24 and episode length=24
# for episode=111: total reward=-22 and episode length=22
# for episode=112: total reward=-20 and episode length=20
# for episode=113: total reward=-19 and episode length=19
# for episode=114: total reward=-21 and episode length=21
# for episode=115: total reward=-23 and episode length=23
# for episode=116: total reward=-43 and episode length=43
# for episode=117: total reward=-21 and episode length=21
# for episode=118: total reward=-22 and episode length=22
# for episode=119: total reward=-19 and episode length=19
# for episode=120: total reward=-17 and episode length=17
# for episode=121: total reward=-17 and episode length=17
# for episode=122: total reward=-19 and episode length=19
# for episode=123: total reward=-21 and episode length=21
# for episode=124: total reward=-17 and episode length=17
# for episode=125: total reward=-20 and episode length=20
# for episode=126: total reward=-19 and episode length=19
# for episode=127: total reward=-22 and episode length=22
# for episode=128: total reward=-18 and episode length=18
# for episode=129: total reward=-17 and episode length=17
# for episode=130: total reward=-18 and episode length=18
# for episode=131: total reward=-19 and episode length=19
# for episode=132: total reward=-20 and episode length=20
# for episode=133: total reward=-17 and episode length=17
# for episode=134: total reward=-19 and episode length=19
# for episode=135: total reward=-21 and episode length=21
# for episode=136: total reward=-38 and episode length=38
# for episode=137: total reward=-18 and episode length=18
# for episode=138: total reward=-21 and episode length=21
# for episode=139: total reward=-20 and episode length=20
# for episode=140: total reward=-17 and episode length=17
# for episode=141: total reward=-17 and episode length=17
# for episode=142: total reward=-17 and episode length=17
# for episode=143: total reward=-19 and episode length=19
# for episode=144: total reward=-19 and episode length=19
# for episode=145: total reward=-18 and episode length=18
# for episode=146: total reward=-22 and episode length=22
# for episode=147: total reward=-20 and episode length=20
# for episode=148: total reward=-21 and episode length=21
# for episode=149: total reward=-19 and episode length=19
# for episode=150: total reward=-124 and episode length=25
# rendering env for episode=151/500
# for episode=151: total reward=-17 and episode length=17
# for episode=152: total reward=-120 and episode length=21
# for episode=153: total reward=-17 and episode length=17
# for episode=154: total reward=-18 and episode length=18
# for episode=155: total reward=-20 and episode length=20
# for episode=156: total reward=-18 and episode length=18
# for episode=157: total reward=-17 and episode length=17
# for episode=158: total reward=-19 and episode length=19
# for episode=159: total reward=-117 and episode length=18
# for episode=160: total reward=-19 and episode length=19
# for episode=161: total reward=-28 and episode length=28
# for episode=162: total reward=-122 and episode length=23
# for episode=163: total reward=-18 and episode length=18
# for episode=164: total reward=-22 and episode length=22
# for episode=165: total reward=-17 and episode length=17
# for episode=166: total reward=-26 and episode length=26
# for episode=167: total reward=-18 and episode length=18
# for episode=168: total reward=-19 and episode length=19
# for episode=169: total reward=-21 and episode length=21
# for episode=170: total reward=-23 and episode length=23
# for episode=171: total reward=-119 and episode length=20
# for episode=172: total reward=-17 and episode length=17
# for episode=173: total reward=-18 and episode length=18
# for episode=174: total reward=-17 and episode length=17
# for episode=175: total reward=-18 and episode length=18
# for episode=176: total reward=-20 and episode length=20
# for episode=177: total reward=-17 and episode length=17
# for episode=178: total reward=-17 and episode length=17
# for episode=179: total reward=-18 and episode length=18
# for episode=180: total reward=-17 and episode length=17
# for episode=181: total reward=-17 and episode length=17
# for episode=182: total reward=-18 and episode length=18
# for episode=183: total reward=-25 and episode length=25
# for episode=184: total reward=-27 and episode length=27
# for episode=185: total reward=-19 and episode length=19
# for episode=186: total reward=-120 and episode length=21
# for episode=187: total reward=-20 and episode length=20
# for episode=188: total reward=-19 and episode length=19
# for episode=189: total reward=-21 and episode length=21
# for episode=190: total reward=-25 and episode length=25
# for episode=191: total reward=-18 and episode length=18
# for episode=192: total reward=-25 and episode length=25
# for episode=193: total reward=-24 and episode length=24
# for episode=194: total reward=-20 and episode length=20
# for episode=195: total reward=-17 and episode length=17
# for episode=196: total reward=-18 and episode length=18
# for episode=197: total reward=-29 and episode length=29
# for episode=198: total reward=-22 and episode length=22
# for episode=199: total reward=-19 and episode length=19
# for episode=200: total reward=-18 and episode length=18
# rendering env for episode=201/500
# for episode=201: total reward=-24 and episode length=24
# for episode=202: total reward=-17 and episode length=17
# for episode=203: total reward=-17 and episode length=17
# for episode=204: total reward=-18 and episode length=18
# for episode=205: total reward=-20 and episode length=20
# for episode=206: total reward=-19 and episode length=19
# for episode=207: total reward=-23 and episode length=23
# for episode=208: total reward=-17 and episode length=17
# for episode=209: total reward=-123 and episode length=24
# for episode=210: total reward=-17 and episode length=17
# for episode=211: total reward=-19 and episode length=19
# for episode=212: total reward=-24 and episode length=24
# for episode=213: total reward=-17 and episode length=17
# for episode=214: total reward=-21 and episode length=21
# for episode=215: total reward=-20 and episode length=20
# for episode=216: total reward=-18 and episode length=18
# for episode=217: total reward=-17 and episode length=17
# for episode=218: total reward=-226 and episode length=28
# for episode=219: total reward=-17 and episode length=17
# for episode=220: total reward=-17 and episode length=17
# for episode=221: total reward=-19 and episode length=19
# for episode=222: total reward=-32 and episode length=32
# for episode=223: total reward=-19 and episode length=19
# for episode=224: total reward=-29 and episode length=29
# for episode=225: total reward=-17 and episode length=17
# for episode=226: total reward=-19 and episode length=19
# for episode=227: total reward=-23 and episode length=23
# for episode=228: total reward=-119 and episode length=20
# for episode=229: total reward=-19 and episode length=19
# for episode=230: total reward=-17 and episode length=17
# for episode=231: total reward=-17 and episode length=17
# for episode=232: total reward=-17 and episode length=17
# for episode=233: total reward=-20 and episode length=20
# for episode=234: total reward=-22 and episode length=22
# for episode=235: total reward=-17 and episode length=17
# for episode=236: total reward=-26 and episode length=26
# for episode=237: total reward=-19 and episode length=19
# for episode=238: total reward=-23 and episode length=23
# for episode=239: total reward=-19 and episode length=19
# for episode=240: total reward=-20 and episode length=20
# for episode=241: total reward=-17 and episode length=17
# for episode=242: total reward=-121 and episode length=22
# for episode=243: total reward=-18 and episode length=18
# for episode=244: total reward=-17 and episode length=17
# for episode=245: total reward=-23 and episode length=23
# for episode=246: total reward=-31 and episode length=31
# for episode=247: total reward=-18 and episode length=18
# for episode=248: total reward=-19 and episode length=19
# for episode=249: total reward=-27 and episode length=27
# for episode=250: total reward=-30 and episode length=30
# rendering env for episode=251/500
# for episode=251: total reward=-30 and episode length=30
# for episode=252: total reward=-22 and episode length=22
# for episode=253: total reward=-19 and episode length=19
# for episode=254: total reward=-19 and episode length=19
# for episode=255: total reward=-21 and episode length=21
# for episode=256: total reward=-19 and episode length=19
# for episode=257: total reward=-21 and episode length=21
# for episode=258: total reward=-21 and episode length=21
# for episode=259: total reward=-20 and episode length=20
# for episode=260: total reward=-19 and episode length=19
# for episode=261: total reward=-23 and episode length=23
# for episode=262: total reward=-28 and episode length=28
# for episode=263: total reward=-17 and episode length=17
# for episode=264: total reward=-24 and episode length=24
# for episode=265: total reward=-17 and episode length=17
# for episode=266: total reward=-17 and episode length=17
# for episode=267: total reward=-17 and episode length=17
# for episode=268: total reward=-21 and episode length=21
# for episode=269: total reward=-19 and episode length=19
# for episode=270: total reward=-18 and episode length=18
# for episode=271: total reward=-20 and episode length=20
# for episode=272: total reward=-21 and episode length=21
# for episode=273: total reward=-18 and episode length=18
# for episode=274: total reward=-22 and episode length=22
# for episode=275: total reward=-17 and episode length=17
# for episode=276: total reward=-19 and episode length=19
# for episode=277: total reward=-22 and episode length=22
# for episode=278: total reward=-24 and episode length=24
# for episode=279: total reward=-17 and episode length=17
# for episode=280: total reward=-21 and episode length=21
# for episode=281: total reward=-19 and episode length=19
# for episode=282: total reward=-17 and episode length=17
# for episode=283: total reward=-17 and episode length=17
# for episode=284: total reward=-20 and episode length=20
# for episode=285: total reward=-17 and episode length=17
# for episode=286: total reward=-19 and episode length=19
# for episode=287: total reward=-18 and episode length=18
# for episode=288: total reward=-17 and episode length=17
# for episode=289: total reward=-18 and episode length=18
# for episode=290: total reward=-21 and episode length=21
# for episode=291: total reward=-24 and episode length=24
# for episode=292: total reward=-124 and episode length=25
# for episode=293: total reward=-119 and episode length=20
# for episode=294: total reward=-17 and episode length=17
# for episode=295: total reward=-21 and episode length=21
# for episode=296: total reward=-17 and episode length=17
# for episode=297: total reward=-19 and episode length=19
# for episode=298: total reward=-17 and episode length=17
# for episode=299: total reward=-21 and episode length=21
# for episode=300: total reward=-18 and episode length=18
# rendering env for episode=301/500
# for episode=301: total reward=-18 and episode length=18
# for episode=302: total reward=-17 and episode length=17
# for episode=303: total reward=-29 and episode length=29
# for episode=304: total reward=-17 and episode length=17
# for episode=305: total reward=-26 and episode length=26
# for episode=306: total reward=-20 and episode length=20
# for episode=307: total reward=-119 and episode length=20
# for episode=308: total reward=-41 and episode length=41
# for episode=309: total reward=-24 and episode length=24
# for episode=310: total reward=-17 and episode length=17
# for episode=311: total reward=-17 and episode length=17
# for episode=312: total reward=-19 and episode length=19
# for episode=313: total reward=-21 and episode length=21
# for episode=314: total reward=-23 and episode length=23
# for episode=315: total reward=-19 and episode length=19
# for episode=316: total reward=-19 and episode length=19
# for episode=317: total reward=-17 and episode length=17
# for episode=318: total reward=-17 and episode length=17
# for episode=319: total reward=-26 and episode length=26
# for episode=320: total reward=-20 and episode length=20
# for episode=321: total reward=-17 and episode length=17
# for episode=322: total reward=-19 and episode length=19
# for episode=323: total reward=-17 and episode length=17
# for episode=324: total reward=-21 and episode length=21
# for episode=325: total reward=-21 and episode length=21
# for episode=326: total reward=-20 and episode length=20
# for episode=327: total reward=-21 and episode length=21
# for episode=328: total reward=-21 and episode length=21
# for episode=329: total reward=-17 and episode length=17
# for episode=330: total reward=-21 and episode length=21
# for episode=331: total reward=-23 and episode length=23
# for episode=332: total reward=-21 and episode length=21
# for episode=333: total reward=-23 and episode length=23
# for episode=334: total reward=-17 and episode length=17
# for episode=335: total reward=-19 and episode length=19
# for episode=336: total reward=-17 and episode length=17
# for episode=337: total reward=-18 and episode length=18
# for episode=338: total reward=-21 and episode length=21
# for episode=339: total reward=-20 and episode length=20
# for episode=340: total reward=-17 and episode length=17
# for episode=341: total reward=-17 and episode length=17
# for episode=342: total reward=-19 and episode length=19
# for episode=343: total reward=-18 and episode length=18
# for episode=344: total reward=-17 and episode length=17
# for episode=345: total reward=-20 and episode length=20
# for episode=346: total reward=-19 and episode length=19
# for episode=347: total reward=-19 and episode length=19
# for episode=348: total reward=-22 and episode length=22
# for episode=349: total reward=-18 and episode length=18
# for episode=350: total reward=-19 and episode length=19
# rendering env for episode=351/500
# for episode=351: total reward=-21 and episode length=21
# for episode=352: total reward=-21 and episode length=21
# for episode=353: total reward=-21 and episode length=21
# for episode=354: total reward=-21 and episode length=21
# for episode=355: total reward=-127 and episode length=28
# for episode=356: total reward=-18 and episode length=18
# for episode=357: total reward=-20 and episode length=20
# for episode=358: total reward=-21 and episode length=21
# for episode=359: total reward=-21 and episode length=21
# for episode=360: total reward=-20 and episode length=20
# for episode=361: total reward=-18 and episode length=18
# for episode=362: total reward=-19 and episode length=19
# for episode=363: total reward=-17 and episode length=17
# for episode=364: total reward=-21 and episode length=21
# for episode=365: total reward=-19 and episode length=19
# for episode=366: total reward=-21 and episode length=21
# for episode=367: total reward=-19 and episode length=19
# for episode=368: total reward=-26 and episode length=26
# for episode=369: total reward=-18 and episode length=18
# for episode=370: total reward=-22 and episode length=22
# for episode=371: total reward=-25 and episode length=25
# for episode=372: total reward=-17 and episode length=17
# for episode=373: total reward=-18 and episode length=18
# for episode=374: total reward=-17 and episode length=17
# for episode=375: total reward=-23 and episode length=23
# for episode=376: total reward=-29 and episode length=29
# for episode=377: total reward=-20 and episode length=20
# for episode=378: total reward=-22 and episode length=22
# for episode=379: total reward=-18 and episode length=18
# for episode=380: total reward=-18 and episode length=18
# for episode=381: total reward=-21 and episode length=21
# for episode=382: total reward=-18 and episode length=18
# for episode=383: total reward=-21 and episode length=21
# for episode=384: total reward=-164 and episode length=65
# for episode=385: total reward=-17 and episode length=17
# for episode=386: total reward=-19 and episode length=19
# for episode=387: total reward=-20 and episode length=20
# for episode=388: total reward=-19 and episode length=19
# for episode=389: total reward=-25 and episode length=25
# for episode=390: total reward=-21 and episode length=21
# for episode=391: total reward=-28 and episode length=28
# for episode=392: total reward=-29 and episode length=29
# for episode=393: total reward=-22 and episode length=22
# for episode=394: total reward=-19 and episode length=19
# for episode=395: total reward=-19 and episode length=19
# for episode=396: total reward=-21 and episode length=21
# for episode=397: total reward=-27 and episode length=27
# for episode=398: total reward=-19 and episode length=19
# for episode=399: total reward=-37 and episode length=37
# for episode=400: total reward=-25 and episode length=25
# rendering env for episode=401/500
# for episode=401: total reward=-19 and episode length=19
# for episode=402: total reward=-40 and episode length=40
# for episode=403: total reward=-21 and episode length=21
# for episode=404: total reward=-28 and episode length=28
# for episode=405: total reward=-22 and episode length=22
# for episode=406: total reward=-21 and episode length=21
# for episode=407: total reward=-17 and episode length=17
# for episode=408: total reward=-22 and episode length=22
# for episode=409: total reward=-207 and episode length=207
# for episode=410: total reward=-27 and episode length=27
# for episode=411: total reward=-43 and episode length=43
# for episode=412: total reward=-66 and episode length=66
# for episode=413: total reward=-21 and episode length=21
# for episode=414: total reward=-23 and episode length=23
# for episode=415: total reward=-31 and episode length=31
# for episode=416: total reward=-150 and episode length=51
# for episode=417: total reward=-20 and episode length=20
# for episode=418: total reward=-21 and episode length=21
# for episode=419: total reward=-17 and episode length=17
# for episode=420: total reward=-20 and episode length=20
# for episode=421: total reward=-18 and episode length=18
# for episode=422: total reward=-19 and episode length=19
# for episode=423: total reward=-20 and episode length=20
# for episode=424: total reward=-17 and episode length=17
# for episode=425: total reward=-19 and episode length=19
# for episode=426: total reward=-17 and episode length=17
# for episode=427: total reward=-33 and episode length=33
# for episode=428: total reward=-21 and episode length=21
# for episode=429: total reward=-23 and episode length=23
# for episode=430: total reward=-17 and episode length=17
# for episode=431: total reward=-18 and episode length=18
# for episode=432: total reward=-24 and episode length=24
# for episode=433: total reward=-19 and episode length=19
# for episode=434: total reward=-22 and episode length=22
# for episode=435: total reward=-28 and episode length=28
# for episode=436: total reward=-25 and episode length=25
# for episode=437: total reward=-17 and episode length=17
# for episode=438: total reward=-28 and episode length=28
# for episode=439: total reward=-20 and episode length=20
# for episode=440: total reward=-20 and episode length=20
# for episode=441: total reward=-25 and episode length=25
# for episode=442: total reward=-24 and episode length=24
# for episode=443: total reward=-19 and episode length=19
# for episode=444: total reward=-17 and episode length=17
# for episode=445: total reward=-19 and episode length=19
# for episode=446: total reward=-17 and episode length=17
# for episode=447: total reward=-19 and episode length=19
# for episode=448: total reward=-20 and episode length=20
# for episode=449: total reward=-17 and episode length=17
# for episode=450: total reward=-20 and episode length=20
# rendering env for episode=451/500
# for episode=451: total reward=-17 and episode length=17
# for episode=452: total reward=-17 and episode length=17
# for episode=453: total reward=-27 and episode length=27
# for episode=454: total reward=-18 and episode length=18
# for episode=455: total reward=-25 and episode length=25
# for episode=456: total reward=-17 and episode length=17
# for episode=457: total reward=-23 and episode length=23
# for episode=458: total reward=-24 and episode length=24
# for episode=459: total reward=-17 and episode length=17
# for episode=460: total reward=-20 and episode length=20
# for episode=461: total reward=-17 and episode length=17
# for episode=462: total reward=-20 and episode length=20
# for episode=463: total reward=-17 and episode length=17
# for episode=464: total reward=-18 and episode length=18
# for episode=465: total reward=-20 and episode length=20
# for episode=466: total reward=-17 and episode length=17
# for episode=467: total reward=-19 and episode length=19
# for episode=468: total reward=-17 and episode length=17
# for episode=469: total reward=-17 and episode length=17
# for episode=470: total reward=-17 and episode length=17
# for episode=471: total reward=-17 and episode length=17
# for episode=472: total reward=-19 and episode length=19
# for episode=473: total reward=-19 and episode length=19
# for episode=474: total reward=-127 and episode length=28
# for episode=475: total reward=-17 and episode length=17
# for episode=476: total reward=-21 and episode length=21
# for episode=477: total reward=-18 and episode length=18
# for episode=478: total reward=-21 and episode length=21
# for episode=479: total reward=-21 and episode length=21
# for episode=480: total reward=-18 and episode length=18
# for episode=481: total reward=-20 and episode length=20
# for episode=482: total reward=-21 and episode length=21
# for episode=483: total reward=-17 and episode length=17
# for episode=484: total reward=-18 and episode length=18
# for episode=485: total reward=-21 and episode length=21
# for episode=486: total reward=-24 and episode length=24
# for episode=487: total reward=-23 and episode length=23
# for episode=488: total reward=-19 and episode length=19
# for episode=489: total reward=-19 and episode length=19
# for episode=490: total reward=-17 and episode length=17
# for episode=491: total reward=-19 and episode length=19
# for episode=492: total reward=-22 and episode length=22
# for episode=493: total reward=-21 and episode length=21
# for episode=494: total reward=-19 and episode length=19
# for episode=495: total reward=-17 and episode length=17
# for episode=496: total reward=-17 and episode length=17
# for episode=497: total reward=-24 and episode length=24
# for episode=498: total reward=-20 and episode length=20
# for episode=499: total reward=-17 and episode length=17
# for episode=500: total reward=-20 and episode length=20

# %%
#what did our agent learnt?
env=gym.make("CliffWalking-v1",render_mode="human")
state,_=env.reset()
done=False
total_reward=0
episode_len=0

while not done:
    action=np.argmax(Q[state])
    state,reward,terminated,truncated,_=env.step(action)
    done=terminated or truncated

    total_reward+=reward
    episode_len+=1

print(f"total reward={total_reward} and episode length={episode_len}")
env.close()
# Out:
# total reward=-17 and episode length=17
