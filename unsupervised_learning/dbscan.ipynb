# %%
from sklearn.datasets import load_iris
from sklearn.preprocessing import StandardScaler
import seaborn as sns

# %%
iris=load_iris()

# %%
X=iris.data
y=iris.target

# %%
sc=StandardScaler()
X_scaled=sc.fit_transform(X)

# %%
sns.scatterplot(x=X_scaled[:,0],y=X_scaled[:,1])
# Out:
# <Axes: >

# %%
from sklearn.cluster import DBSCAN
dbscan=DBSCAN(
    eps=0.8,
    min_samples=5
)
labels=dbscan.fit_predict(X_scaled)

# %%
sns.scatterplot(x=X_scaled[:,0],y=X_scaled[:,1],c=labels)
# Out:
# <Axes: >

# %%
#NON-LINEAR DATA
from sklearn.datasets import make_moons
X,y=make_moons(
    n_samples=300,
    noise=0.05,
    random_state=42
)
X_scaled=sc.fit_transform(X)
sns.scatterplot(x=X[:,0],y=X[:,1])
# Out:
# <Axes: >

# %%
from sklearn.cluster import KMeans
kmeans=KMeans(n_clusters=2,random_state=42)
labels=kmeans.fit_predict(X_scaled)
sns.scatterplot(x=X[:,0],y=X[:,1],c=labels)
# Out:
# c:\Users\RADHAGOPINATH\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1419: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=2.
#   warnings.warn(
# <Axes: >

# %%
db=DBSCAN(eps=0.5,min_samples=5)
labels=db.fit_predict(X_scaled)
sns.scatterplot(x=X[:,0],y=X[:,1],c=labels)
# Out:
# <Axes: >
